# %%
import sys
sys.path.append('..')
from src.preprocessing import preprocess

X_train, X_test, y_train, y_test = preprocess(
    "../data/Scenario A1-ARFF/TimeBasedFeatures-Dataset-15s-VPN.arff"
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 3
#       1 import sys
#       2 sys.path.append('..')
# ----> 3 from src.preprocessing import preprocess
#       4
#       5 X_train, X_test, y_train, y_test = preprocess(
#       6     "../data/Scenario A1-ARFF/TimeBasedFeatures-Dataset-15s-VPN.arff"
#
# ImportError: cannot import name 'preprocess' from 'src.preprocessing' (/home/insomne/Clasificador-Trafico-Encriptado/notebooks/../src/preprocessing.py)
