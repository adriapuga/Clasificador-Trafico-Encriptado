# %%
import sys
sys.path.append('..')
import joblib
from src.features import plot_feature_importance

rf = joblib.load('../models/random_forest.pkl')
df_importance = plot_feature_importance(rf)
print(df_importance.head(10))
# Out:
# Guardado en results/feature_importance.png
#               feature  importance
# 0          total_biat    0.106744
# 1  flowBytesPerSecond    0.086483
# 2         min_flowiat    0.075243
# 3         max_flowiat    0.069982
# 4   flowPktsPerSecond    0.067698
# 5        mean_flowiat    0.062554
# 6          total_fiat    0.060440
# 7            max_biat    0.060117
# 8            max_fiat    0.059568
# 9         std_flowiat    0.052655
